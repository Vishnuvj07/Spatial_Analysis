# %%
from shapely.geometry import Point, LineString, Polygon, MultiPoint, MultiLineString, MultiPolygon
import geopandas as gpd
import matplotlib

# %%
pol = Polygon([(1,0), (0,3), (4,1), (1,0)])
pol
pol.area
# Out:
# 5.0

# %%
datapath = gpd.datasets.get_path("naturalearth_lowres")
world_gdf = gpd.read_file(datapath)
world_gdf
# Out:
# C:\Users\alpha\AppData\Local\Temp\ipykernel_26148\148867795.py:1: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   datapath = gpd.datasets.get_path("naturalearth_lowres")
#          pop_est      continent                      name iso_a3  gdp_md_est  \
# 0       889953.0        Oceania                      Fiji    FJI        5496
# 1     58005463.0         Africa                  Tanzania    TZA       63177
# 2       603253.0         Africa                 W. Sahara    ESH         907
# 3     37589262.0  North America                    Canada    CAN     1736425
# 4    328239523.0  North America  United States of America    USA    21433226
# ..           ...            ...                       ...    ...         ...
# 172    6944975.0         Europe                    Serbia    SRB       51475
# 173     622137.0         Europe                Montenegro    MNE        5542
# 174    1794248.0         Europe                    Kosovo    -99        7926
# 175    1394973.0  North America       Trinidad and Tobago    TTO       24269
# 176   11062113.0         Africa                  S. Sudan    SSD       11998
#
#                                               geometry
# 0    MULTIPOLYGON (((180.00000 -16.06713, 180.00000...
# 1    POLYGON ((33.90371 -0.95000, 34.07262 -1.05982...
# 2    POLYGON ((-8.66559 27.65643, -8.66512 27.58948...
# 3    MULTIPOLYGON (((-122.84000 49.00000, -122.9742...
# 4    MULTIPOLYGON (((-122.84000 49.00000, -120.0000...
# ..                                                 ...
# 172  POLYGON ((18.82982 45.90887, 18.82984 45.90888...
# 173  POLYGON ((20.07070 42.58863, 19.80161 42.50009...
# 174  POLYGON ((20.59025 41.85541, 20.52295 42.21787...
# 175  POLYGON ((-61.68000 10.76000, -61.10500 10.890...
# 176  POLYGON ((30.83385 3.50917, 29.95350 4.17370, ...
#
# [177 rows x 6 columns]

# %%
world_gdf.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
world_gdf = world_gdf.to_crs("+proj=eck4 +lon_0=0 +x_0=0 +y_0=0 +datum=WGS84 +units=m +no_defs")
world_gdf.crs
# Out:
# <Projected CRS: +proj=eck4 +lon_0=0 +x_0=0 +y_0=0 +datum=WGS84 +un ...>
# Name: unknown
# Axis Info [cartesian]:
# - E[east]: Easting (metre)
# - N[north]: Northing (metre)
# Area of Use:
# - undefined
# Coordinate Operation:
# - name: unknown
# - method: Eckert IV
# Datum: World Geodetic System 1984
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
world_gdf['area'] = world_gdf.area * 10**6
world_gdf
# Out:
#          pop_est      continent                      name iso_a3  gdp_md_est  \
# 0       889953.0        Oceania                      Fiji    FJI        5496
# 1     58005463.0         Africa                  Tanzania    TZA       63177
# 2       603253.0         Africa                 W. Sahara    ESH         907
# 3     37589262.0  North America                    Canada    CAN     1736425
# 4    328239523.0  North America  United States of America    USA    21433226
# ..           ...            ...                       ...    ...         ...
# 172    6944975.0         Europe                    Serbia    SRB       51475
# 173     622137.0         Europe                Montenegro    MNE        5542
# 174    1794248.0         Europe                    Kosovo    -99        7926
# 175    1394973.0  North America       Trinidad and Tobago    TTO       24269
# 176   11062113.0         Africa                  S. Sudan    SSD       11998
#
#                                               geometry          area
# 0    MULTIPOLYGON (((16656124.269 -2101233.685, 166...  1.939256e+16
# 1    POLYGON ((3187000.863 -125226.236, 3202835.644...  9.388480e+17
# 2    POLYGON ((-776816.036 3559764.608, -776957.139...  9.715654e+16
# 3    MULTIPOLYGON (((-9864573.103 5970912.623, -987...  1.000183e+19
# 4    MULTIPOLYGON (((-9864573.103 5970912.623, -963...  9.520906e+18
# ..                                                 ...           ...
# 172  POLYGON ((1543684.194 5651802.662, 1543685.232...  7.639132e+16
# 173  POLYGON ((1679092.287 5296056.359, 1657432.493...  1.345279e+16
# 174  POLYGON ((1729835.296 5215797.259, 1720611.181...  1.123850e+16
# 175  POLYGON ((-5757592.860 1413369.183, -5702937.7...  7.790176e+15
# 176  POLYGON ((2896421.987 462407.551, 2812852.389 ...  6.289622e+17
#
# [177 rows x 7 columns]

# %%
world_gdf['pop_density'] = world_gdf.pop_est / world_gdf.area * 10**6

world_gdf.sort_values(by='pop_density', ascending=False)
# Out:
#          pop_est                continent                    name iso_a3  \
# 99   163046161.0                     Asia              Bangladesh    BGD
# 79     4685306.0                     Asia               Palestine    PSE
# 140   23568378.0                     Asia                  Taiwan    TWN
# 77     6855713.0                     Asia                 Lebanon    LBN
# 169   12626950.0                   Africa                  Rwanda    RWA
# ..           ...                      ...                     ...    ...
# 97     3225167.0                     Asia                Mongolia    MNG
# 20        3398.0            South America            Falkland Is.    FLK
# 22       56225.0            North America               Greenland    GRL
# 23         140.0  Seven seas (open ocean)  Fr. S. Antarctic Lands    ATF
# 159       4490.0               Antarctica              Antarctica    ATA
#
#      gdp_md_est                                           geometry  \
# 99       302571  POLYGON ((8455037.031 2862141.705, 8469605.972...
# 79        16276  POLYGON ((3127401.561 4023733.541, 3087561.638...
# 140     1127000  POLYGON ((11034560.069 3156825.603, 11032285.2...
# 77        51991  POLYGON ((3141154.397 4236334.349, 3117804.289...
# 169       10354  POLYGON ((2859375.715 -149565.705, 2896415.181...
# ..          ...                                                ...
# 97        13996  POLYGON ((7032142.671 6000941.853, 7107939.605...
# 20          282  POLYGON ((-4814015.486 -6253920.632, -4740858....
# 22         3051  POLYGON ((-2555525.099 8347965.820, -2346518.8...
# 23           16  POLYGON ((5550199.759 -5932855.132, 5589906.67...
# 159         898  MULTIPOLYGON (((-2870542.982 -8180812.656, -28...
#
#              area  pop_density
# 99   1.343242e+17  1213.825913
# 79   5.051181e+15   927.566405
# 140  3.447494e+16   683.638053
# 77   1.012080e+16   677.388357
# 169  2.352168e+16   536.821849
# ..            ...          ...
# 97   1.543781e+18     2.089135
# 20   1.634295e+16     0.207918
# 22   2.194863e+18     0.025617
# 23   1.157860e+16     0.012091
# 159  1.224505e+19     0.000367
#
# [177 rows x 8 columns]

# %%
figsize = (20, 11)

world_gdf.plot('pop_density', legend=True, figsize=figsize);

# %%
norm = matplotlib.colors.LogNorm(vmin=world_gdf.pop_density.min(), vmax=world_gdf.pop_density.max())

world_gdf.to_crs('epsg:4326').plot("pop_density", 
                                   figsize=figsize, 
                                   legend=True,  
                                   norm=norm);
